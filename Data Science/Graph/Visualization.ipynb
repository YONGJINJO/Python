# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/broadcast.csv", index_col = 0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.plot()

# %%
df.plot(y = 'KBS')

# %%
df.plot(y = ['KBS', 'JTBC'])

# %%
df[['KBS', 'JTBC']].plot()

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/gdp.csv", index_col = 0)
sorted(df.columns)
# Out:
# ['Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
# ...

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/sports.csv", index_col = 0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot()

# %%
df.plot(kind = 'bar')

# %%
df.plot(kind = 'barh')

# %%
df.plot(kind = 'bar', stacked = True)

# %%
df['Female'].plot(kind = 'bar')

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/silicon_valley_summary.csv")

df
# Out:
#      job_category             race_ethnicity  gender   count  percentage
# 0     All workers                      White    Male  268883   41.257252
# 1     All workers                      White  Female  105560   16.197065
# 2     All workers  Black_or_African American    Male   17508    2.686417
# 3     All workers  Black_or_African American  Female   11479    1.761331
# 4     All workers                      Asian    Male  125347   19.233171
# 5     All workers                      Asian  Female   58049    8.907005
# 6     All workers         Hispanic_or_Latino    Male   32201    4.940903
# 7     All workers         Hispanic_or_Latino  Female   15512    2.380152
# 8     All workers                        All    Male  454813   69.786244
# 9     All workers                        All  Female  196910   30.213756
# 10    All workers                     Totals    Both  651723  100.000000
# 11     Executives                      White    Male    7282   58.678485
# ...

# %%
part = df[(df['job_category'] == 'Managers') & (df['gender'] == 'Male') & (df['race_ethnicity'] != 'All')]
part
# Out:
#    job_category             race_ethnicity gender  count  percentage
# 22     Managers                      White   Male  48311   46.479253
# 24     Managers  Black_or_African American   Male   1575    1.515283
# 26     Managers                      Asian   Male  18563   17.859170
# 28     Managers         Hispanic_or_Latino   Male   3741    3.599157

# %%
part.plot(kind = 'barh', x = 'race_ethnicity', y = 'count')

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/broadcast.csv", index_col = 0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.loc[2017].plot(kind = 'pie')

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/silicon_valley_details.csv")
df
# Out:
#       company  year                race gender          job_category  count
# 0     23andMe  2016  Hispanic_or_Latino   male            Executives      0
# 1     23andMe  2016  Hispanic_or_Latino   male              Managers      1
# 2     23andMe  2016  Hispanic_or_Latino   male         Professionals      7
# 3     23andMe  2016  Hispanic_or_Latino   male           Technicians      0
# 4     23andMe  2016  Hispanic_or_Latino   male         Sales workers      0
# ...       ...   ...                 ...    ...                   ...    ...
# 4435  Sanmina  2016      Overall_totals    NaN  laborers and helpers      4
# 4436  Sanmina  2016      Overall_totals    NaN       Service workers     57
# 4437  Sanmina  2016      Overall_totals    NaN                Totals   5205
# 4438  Sanmina  2016      Overall_totals    NaN       Previous_totals   5615
# 4439  Sanmina  2016      Overall_totals    NaN              Managers    591
#
# [4440 rows x 6 columns]

# %%
df1 = df[(df['count'] != 0) & (df['company'] == 'Adobe') & (df['race'] == 'Overall_totals') & (df['job_category'] != 'Totals') & (df['job_category'] != 'Previous_totals')]

# %%
df1.set_index('job_category', inplace = True)
df1.plot(kind = 'pie', y = 'count')

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/body.csv", index_col = 0)
df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
df.plot(kind = 'hist', y = 'Height')

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/starbucks_drinks.csv")
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 214  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 215  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 216  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 217  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 218  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.plot(kind = 'hist', y = 'Calories', bins = 20)

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/exam.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
df.plot(kind = 'box', y = 'math score')

# %%
df.plot(kind = 'box', y = ['math score', 'reading score', 'writing score'])

# %%
df.plot(kind = 'scatter', x = 'math score', y = 'reading score')

# %%
df.plot(kind = 'scatter', x = 'math score', y = 'writing score')

# %%
df.plot(kind = 'scatter', x = 'reading score', y = 'writing score')

# %%
df = pd.read_csv("C:/Users/choyj/Desktop/Python/Data_Science/Graph/world_indexes.csv")
df
# Out:
#                            Id  Human Development Index HDI-2014  \
# 0                      Norway                          0.943877
# 1                   Australia                          0.934958
# 2                 Switzerland                          0.929613
# 3                     Denmark                          0.923328
# 4                 Netherlands                          0.921794
# ..                        ...                               ...
# 183                   Burundi                          0.399928
# 184                      Chad                          0.391906
# 185                   Eritrea                          0.390899
# 186  Central African Republic                          0.350131
# 187                     Niger                          0.348254
#
#      Gini coefficient 2005-2013  \
# 0                         26.83
# 1                         34.01
# 2                         32.35
# 3                         26.88
# ...

# %%
sorted(df.columns)
# Out:
# ['Adolescent birth rate 15-19 per 100k 20102015',
#  'Birth registration funder age 5 2005-2013',
#  'Carbon dioxide emissions per capita 2011 Tones',
#  'Carbon dioxide emissionsAverage annual growth',
#  'Change forest percentable 1900 to 2012',
#  'Change mobile usage 2009 2014',
#  'Consumer price index 2013',
#  'Domestic credit provided by financial sector 2013',
#  'Domestic food price level 2009 2014 index',
#  'Domestic food price level 2009-2014 volitility index',
#  'Electrification rate or population',
#  'Expected years of schooling - Years',
#  'Exports and imports percentage GPD 2013',
#  'Female Suicide Rate 100k people',
#  'Foreign direct investment net inflows percentage GDP 2013',
#  'Forest area percentage of total land area 2012',
#  'Fossil fuels percentage of total 2012',
#  'Fresh water withdrawals 2005',
#  'Gender Inequality Index 2014',
#  'General government final consumption expenditure - Annual growth 2005 2013',
# ...

# %%
df.plot(kind = 'scatter', x = 'Life expectancy at birth- years', y = 'Internet users percentage of population 2014' )

# %% [markdown]
# Exploratory Data Analysis
# 탐색적 데이터 분석 : 주어진 데이터를 다양한 관점에서 살펴보고 탐색하여 인사이트를 찾아내는 것
#
# - 각 row/column은 어떤 정보를 나타내는지?
# - row와 column은 어떤 연관이 있는지 등

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/choyj/Desktop/Python/Data_Science/Graph/young_survey.csv')

# %%
df
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 992    5.0                       2.0    5.0   2.0      2.0              5.0
# 993    4.0                       4.0    5.0   1.0      3.0              4.0
# 994    4.0                       3.0    1.0   1.0      2.0              2.0
# 995    5.0                       3.0    3.0   3.0      1.0              3.0
# 996    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
basic_info = df.iloc[:, 140:]
basic_info
# Out:
#       Age  Height  Weight  Number of siblings  Gender Handedness  \
# 0    20.0   163.0    48.0                 1.0  female      right
# 1    19.0   163.0    58.0                 2.0  female      right
# 2    20.0   176.0    67.0                 2.0  female      right
# 3    22.0   172.0    59.0                 1.0  female      right
# 4    20.0   170.0    59.0                 1.0  female      right
# ..    ...     ...     ...                 ...     ...        ...
# 992  20.0   164.0    57.0                 1.0  female      right
# 993  27.0   183.0    80.0                 5.0    male       left
# 994  18.0   173.0    75.0                 0.0  female      right
# 995  25.0   173.0    58.0                 1.0  female      right
# 996  21.0   185.0    72.0                 1.0    male      right
#
#              Education
# 0    bachelor's degree
# 1    bachelor's degree
# 2          high school
# 3    bachelor's degree
# 4          high school
# ..                 ...
# ...

# %%
basic_info.describe()
# Out:
#               Age      Height      Weight  Number of siblings
# count  997.000000  982.000000  981.000000          995.000000
# mean    20.439318  173.610998   66.407747            1.300503
# std      2.835443    9.373842   13.862403            1.015548
# min     15.000000  148.000000   41.000000            0.000000
# 25%     19.000000  167.000000   55.000000            1.000000
# 50%     20.000000  173.000000   64.000000            1.000000
# 75%     22.000000  180.000000   75.000000            2.000000
# max     30.000000  203.000000  165.000000           10.000000

# %%
basic_info['Gender'].value_counts()
# Out:
# female    587
# male      405
# Name: Gender, dtype: int64

# %%
basic_info['Handedness'].value_counts()
# Out:
# right    895
# left      99
# Name: Handedness, dtype: int64

# %%
basic_info['Education'].value_counts()
# Out:
# high school          618
# bachelor's degree    207
# middle school         78
# master's degree       78
# elementary school     10
# doctorate degree       5
# Name: Education, dtype: int64

# %%
sns.violinplot(data = basic_info, y = 'Age')

# %%
sns.violinplot(data = basic_info, x= 'Gender', y = 'Age')

# %%
sns.violinplot(data = basic_info, x= 'Gender', y = 'Age', hue = 'Handedness')

# %%
sns.jointplot(data = basic_info, x = 'Height', y = 'Weight')

# %%
occupation_df = pd.read_csv('C:/Users/choyj/Desktop/Python/Data_Science/Graph/occupations.csv')

# %%
occupation_df
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
female_info = occupation_df[occupation_df['gender'] == 'F']
female_info
# Out:
#      user_id  age gender  occupation zip_code
# 1          2   53      F       other    94043
# 4          5   33      F       other    15213
# 10        11   39      F       other    30329
# 11        12   28      F       other    06405
# 14        15   49      F    educator    97301
# ..       ...  ...    ...         ...      ...
# 924      925   18      F    salesman    49036
# 929      930   28      F   scientist    07310
# 937      938   38      F  technician    55038
# 938      939   26      F     student    33319
# 941      942   48      F   librarian    78209
#
# [273 rows x 5 columns]

# %%
female_info['occupation'].value_counts()
# Out:
# student          60
# administrator    36
# other            36
# librarian        29
# educator         26
# writer           19
# artist           13
# healthcare       11
# marketing        10
# homemaker         6
# programmer        6
# none              4
# scientist         3
# salesman          3
# executive         3
# entertainment     2
# engineer          2
# lawyer            2
# technician        1
# retired           1
# Name: occupation, dtype: int64

# %%
male_info = occupation_df[occupation_df['gender'] == 'M']
male_info['occupation'].value_counts()
# Out:
# student          136
# other             69
# educator          69
# engineer          65
# programmer        60
# administrator     43
# executive         29
# scientist         28
# writer            26
# technician        26
# librarian         22
# entertainment     16
# marketing         16
# artist            15
# retired           13
# lawyer            10
# salesman           9
# doctor             7
# healthcare         5
# none               5
# homemaker          1
# Name: occupation, dtype: int64

# %%
music = df.iloc[:, :19]
music
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 992    5.0                       2.0    5.0   2.0      2.0              5.0
# 993    4.0                       4.0    5.0   1.0      3.0              4.0
# 994    4.0                       3.0    1.0   1.0      2.0              2.0
# 995    5.0                       3.0    3.0   3.0      1.0              3.0
# 996    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
music.describe()
# Out:
#             Music  Slow songs or fast songs       Dance        Folk  \
# count  994.000000                995.000000  993.000000  992.000000
# mean     4.737425                  3.334673    3.115811    2.293347
# std      0.650716                  0.830477    1.169023    1.140767
# min      1.000000                  1.000000    1.000000    1.000000
# 25%      5.000000                  3.000000    2.000000    1.000000
# 50%      5.000000                  3.000000    3.000000    2.000000
# 75%      5.000000                  4.000000    4.000000    3.000000
# max      5.000000                  5.000000    5.000000    5.000000
#
#           Country  Classical music     Musical         Pop        Rock  \
# count  992.000000       990.000000  995.000000  994.000000  991.000000
# mean     2.121976         2.956566    2.767839    3.476861    3.769929
# std      1.079224         1.253965    1.258920    1.157300    1.182167
# ...

# %%
heat_music = sns.heatmap(music.corr(), cmap='coolwarm')
heat_music.get_ylim()
heat_music.set_ylim(19,0)
heat_music

# %%
df.corr()
# Out:
#                                Music  Slow songs or fast songs     Dance  \
# Music                       1.000000                  0.075426  0.066719
# Slow songs or fast songs    0.075426                  1.000000  0.188217
# Dance                       0.066719                  0.188217  1.000000
# Folk                        0.027648                 -0.062023  0.065863
# Country                    -0.014272                 -0.072138  0.055106
# ...                              ...                       ...       ...
# Spending on healthy eating  0.073037                 -0.027398  0.026210
# Age                        -0.078058                  0.010998  0.031215
# Height                     -0.068002                  0.106873 -0.012681
# Weight                     -0.128233                  0.125870  0.014024
# Number of siblings         -0.011585                  0.002352  0.003952
#
#                                 Folk   Country  Classical music   Musical  \
# ...

# %%
df.corr()['Age'].sort_values(ascending = False)
# Out:
# Age                        1.000000
# Weight                     0.238893
# Elections                  0.212319
# Prioritising workload      0.156256
# Reliability                0.148141
#                              ...
# Mood swings               -0.111890
# Getting up                -0.119888
# Questionnaires or polls   -0.128187
# Shopping centres          -0.133800
# Changing the past         -0.146895
# Name: Age, Length: 139, dtype: float64

# %%
correlation = df.corr()['Getting up']
correlation[:19].sort_values(ascending = True)
# Out:
# Opera                      -0.071819
# Slow songs or fast songs   -0.052613
# Folk                       -0.049612
# Punk                       -0.029189
# Metal or Hardrock          -0.026769
# Country                    -0.025315
# Latino                     -0.015060
# Reggae, Ska                -0.008434
# Musical                     0.011869
# Classical music             0.014285
# Swing, Jazz                 0.019556
# Techno, Trance              0.019863
# Dance                       0.027249
# Alternative                 0.027540
# Rock n roll                 0.028889
# Hiphop, Rap                 0.038980
# Pop                         0.079101
# Music                       0.090009
# Rock                        0.105245
# Name: Getting up, dtype: float64

# %%
df.corr()['Branded clothing']['Spending on looks']
# Out:
# 0.4183989446458914

# %%
df.corr()['Musical instruments']['Writing']
# Out:
# 0.34381621439042986

# %%
df.corr()['Writing notes']['New environment']
# Out:
# -0.07939652994810564

# %%
df.corr()['Workaholism']['Healthy eating']
# Out:
# 0.23864443283866651

# %%
interst = df.loc[:, 'History':'Pets']
interst.head()
# Out:
#    History  Psychology  Politics  Mathematics  Physics  Internet   PC  \
# 0      1.0         5.0       1.0          3.0      3.0       5.0  3.0
# 1      1.0         3.0       4.0          5.0      2.0       4.0  4.0
# 2      1.0         2.0       1.0          5.0      2.0       4.0  2.0
# 3      4.0         4.0       5.0          4.0      1.0       3.0  1.0
# 4      3.0         2.0       3.0          2.0      2.0       2.0  2.0
#
#    Economy Management  Biology  Chemistry  ...  Passive sport  Active sport  \
# 0                 5.0      3.0        3.0  ...            1.0           5.0
# 1                 5.0      1.0        1.0  ...            1.0           1.0
# 2                 4.0      1.0        1.0  ...            5.0           2.0
# 3                 2.0      3.0        3.0  ...            1.0           1.0
# 4                 2.0      3.0        3.0  ...            3.0           1.0
#
#    Gardening  Celebrities  Shopping  Science and technology  Theatre  \
# ...

# %%
corr = interst.corr()
corr
# Out:
#                          History  Psychology  Politics  Mathematics   Physics  \
# History                 1.000000    0.281493  0.400845     0.008328  0.079638
# Psychology              0.281493    1.000000  0.195338     0.043030  0.065774
# Politics                0.400845    0.195338  1.000000     0.104033  0.130293
# Mathematics             0.008328    0.043030  0.104033     1.000000  0.595188
# Physics                 0.079638    0.065774  0.130293     0.595188  1.000000
# Internet                0.022010    0.000075  0.058863     0.157779  0.103793
# PC                      0.027346   -0.077712  0.088846     0.295564  0.339429
# Economy Management      0.054872    0.087072  0.304575     0.218796  0.010678
# Biology                 0.014807    0.202913 -0.090532     0.078043  0.212261
# Chemistry               0.014117    0.058541 -0.058849     0.181953  0.322827
# Reading                 0.262948    0.231861  0.089448    -0.033184 -0.062080
# ...

# %%
corr['History'].sort_values(ascending = False)
# Out:
# History                   1.000000
# Politics                  0.400845
# Geography                 0.327354
# Law                       0.298363
# Psychology                0.281493
# Reading                   0.262948
# Religion                  0.203840
# Art exhibitions           0.200643
# Theatre                   0.185301
# Writing                   0.164617
# Foreign languages         0.145471
# Science and technology    0.135597
# Musical instruments       0.107279
# Countryside, outdoors     0.096609
# Physics                   0.079638
# Active sport              0.064929
# Adrenaline sports         0.061201
# Economy Management        0.054872
# Cars                      0.050644
# Medicine                  0.040023
# Gardening                 0.033196
# Dancing                   0.032925
# Pets                      0.031920
# PC                        0.027346
# Fun with friends          0.024960
# Internet                  0.022010
# Biology                   0.014807
# ...

# %%
sns.clustermap(corr)

# %%
survey = pd.read_csv('C:/Users/choyj/Desktop/Python/Data_Science/Graph/survey.csv')
survey
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 992    5.0                       2.0    5.0   2.0      2.0              5.0
# 993    4.0                       4.0    5.0   1.0      3.0              4.0
# 994    4.0                       3.0    1.0   1.0      2.0              2.0
# 995    5.0                       3.0    3.0   3.0      1.0              3.0
# 996    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
movie = survey.loc[:,'Horror':'Action']

# %%
corr = movie.corr()
sns.clustermap(corr)

# %%
titanic = pd.read_csv('C:/Users/choyj/Desktop/Python/Data_Science/Graph/titanic.csv', index_col = 0)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
age = titanic['Age']
age.plot(kind = 'hist', bins = 8)

# %%
sns.catplot(data = titanic, x = 'Age', y = 'Fare', kind = 'strip')

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic.corr()['Age']['Survived']
# Out:
# -0.07722109457217737

# %%
titanic.corr()['Age']['Fare']
# Out:
# 0.09606669176903881

# %%
women = titanic[titanic['Sex'] == 'female']
men = titanic[titanic['Sex'] == 'male']

women['Survived'].value_counts()
# Out:
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
men['Survived'].value_counts()
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
titanic.plot(kind = 'scatter', x = 'Age', y = 'Fare')

# %%
sns.catplot(data = titanic, x = 'Survived', y = 'Age', kind = 'strip', hue = 'Sex')
